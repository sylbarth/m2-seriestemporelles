# %%
# !pip3 install statsmodels
# !pip3 install matplotlib
# !pip3 install seaborn
# !pip3 install scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from statsmodels) (2.3.2)
# Requirement already satisfied: packaging>=21.3 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: numpy>=1.23 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: packaging>=20.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: pandas>=1.2 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: cycler>=0.10 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from sklearn) (1.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (3.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sylbarth/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sklearn) (1.5.2)
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
pop = pd.read_csv('../datasets/uspop.csv')
pop.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pop = pd.read_csv('../datasets/uspop.csv')
#       2 pop.head(10)
#
# NameError: name 'pd' is not defined

# %%
pop.shape
# Out:
# (19, 2)

# %%
pop.dtypes
# Out:
# date       int64
# uspop    float64
# dtype: object

# %%
pop['uspop'] = pd.to_numeric(pop['uspop'], errors='coerce')
pop['date'] = pd.to_datetime(pop['date'], format="%Y").dt.date

# %%
pop
# Out:
#           date   uspop
# 0   1790-01-01    3.93
# 1   1800-01-01    5.31
# 2   1810-01-01    7.24
# 3   1820-01-01    9.64
# 4   1830-01-01   12.90
# 5   1840-01-01   17.10
# 6   1850-01-01   23.20
# 7   1860-01-01   31.40
# 8   1870-01-01   39.80
# 9   1880-01-01   50.20
# 10  1890-01-01   62.90
# 11  1900-01-01   76.00
# 12  1910-01-01   92.00
# 13  1920-01-01  105.70
# 14  1930-01-01  122.80
# 15  1940-01-01  131.70
# 16  1950-01-01  151.30
# 17  1960-01-01  179.30
# 18  1970-01-01  203.20

# %%
pop.dropna(inplace=True)

# %%
pop.set_index('date', inplace=True)

# %%
print(pop)
# Out:
#              uspop
# date
# 1790-01-01    3.93
# 1800-01-01    5.31
# 1810-01-01    7.24
# 1820-01-01    9.64
# 1830-01-01   12.90
# 1840-01-01   17.10
# 1850-01-01   23.20
# 1860-01-01   31.40
# 1870-01-01   39.80
# 1880-01-01   50.20
# 1890-01-01   62.90
# 1900-01-01   76.00
# 1910-01-01   92.00
# 1920-01-01  105.70
# 1930-01-01  122.80
# 1940-01-01  131.70
# 1950-01-01  151.30
# 1960-01-01  179.30
# 1970-01-01  203.20

# %%
fig, ax = plt.subplots(figsize=(16, 9))
fig.autofmt_xdate()
ax.plot(pop.uspop, label='US Pop', color='tab:blue')
ax.legend()
ax.grid()
ax.set(xlabel='Date',ylabel='US Population')
# Out:
# [Text(0.5, 0, 'Date'), Text(0, 0.5, 'US Population')]

# %%
# pop["dluspop"] = np.log(pop.uspop) - np.log(pop.uspop.shift(1))
# print(pop)
# pop["dluspop"].plot(figsize=(16, 9))
# fig, ax = plt.subplots(figsize=(16, 9))
# fig.autofmt_xdate()
# ax.plot(dlog, label='Log(US Pop)', color='tab:blue')
# ax.legend()
# ax.grid()
# ax.set(xlabel='Date',ylabel='US Population')

# %%
pop["uspop_1"] = pop["uspop"].shift(1)
print(pop)
# Out:
#              uspop  uspop_1
# date
# 1790-01-01    3.93      NaN
# 1800-01-01    5.31     3.93
# 1810-01-01    7.24     5.31
# 1820-01-01    9.64     7.24
# 1830-01-01   12.90     9.64
# 1840-01-01   17.10    12.90
# 1850-01-01   23.20    17.10
# 1860-01-01   31.40    23.20
# 1870-01-01   39.80    31.40
# 1880-01-01   50.20    39.80
# 1890-01-01   62.90    50.20
# 1900-01-01   76.00    62.90
# 1910-01-01   92.00    76.00
# 1920-01-01  105.70    92.00
# 1930-01-01  122.80   105.70
# 1940-01-01  131.70   122.80
# 1950-01-01  151.30   131.70
# 1960-01-01  179.30   151.30
# 1970-01-01  203.20   179.30

# %%
pop = pop.dropna()
print(pop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pop = pop.dropna()
#       2 print(pop)
#
# NameError: name 'pop' is not defined

# %%
import timeseries
timeseries.plot(pop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import timeseries
# ----> 2 timeseries.plot(pop)
#
# NameError: name 'pop' is not defined

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# import sys
# sys.path.append('/content/gdrive/mypythondirectory')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       3 import sys
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
train = pop.iloc[:10]
test  = pop.iloc[10:]
print(train)
print(test)
print(train.columns)
# Out:
#             uspop  uspop_1
# date
# 1800-01-01   5.31     3.93
# 1810-01-01   7.24     5.31
# 1820-01-01   9.64     7.24
# 1830-01-01  12.90     9.64
# 1840-01-01  17.10    12.90
# 1850-01-01  23.20    17.10
# 1860-01-01  31.40    23.20
# 1870-01-01  39.80    31.40
# 1880-01-01  50.20    39.80
# 1890-01-01  62.90    50.20
#             uspop  uspop_1
# date
# 1900-01-01   76.0     62.9
# 1910-01-01   92.0     76.0
# 1920-01-01  105.7     92.0
# 1930-01-01  122.8    105.7
# 1940-01-01  131.7    122.8
# 1950-01-01  151.3    131.7
# 1960-01-01  179.3    151.3
# 1970-01-01  203.2    179.3
# Index(['uspop', 'uspop_1'], dtype='object')

# %%
train_x = train.loc[:,~train.columns.isin(["date","uspop"])]
train_y = train["uspop"]
print(train_x)
print(train_y)
# Out:
#             uspop_1
# date
# 1800-01-01     3.93
# 1810-01-01     5.31
# 1820-01-01     7.24
# 1830-01-01     9.64
# 1840-01-01    12.90
# 1850-01-01    17.10
# 1860-01-01    23.20
# 1870-01-01    31.40
# 1880-01-01    39.80
# 1890-01-01    50.20
# date
# 1800-01-01     5.31
# 1810-01-01     7.24
# 1820-01-01     9.64
# 1830-01-01    12.90
# 1840-01-01    17.10
# 1850-01-01    23.20
# 1860-01-01    31.40
# 1870-01-01    39.80
# 1880-01-01    50.20
# 1890-01-01    62.90
# Name: uspop, dtype: float64

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestRegressor

rf  = RandomForestRegressor(n_estimators=100, random_state=1, oob_score=True)
fit = rf.fit(train_x, train_y)

# %%
from sklearn.metrics import mean_squared_error, r2_score

def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# Access the OOB Score
# oob_score = fit.oob_score_
# print(f'Out-of-Bag Score: {oob_score}')

# Making predictions on the same data or new data
predictions = fit.predict(train_x)

# Evaluating the model
mse = mean_squared_error(train_y, predictions)
rmse = rmse(train_y, predictions)
print(f'Mean Squared Error: {mse}')
print(f'RMSE: {rmse}')

r2 = r2_score(train_y, predictions)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 4.16070711900006
# RMSE: 2.0397811448780625
# R-squared: 0.9880204116754426

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Assuming regressor is your trained Random Forest model
# Pick one tree from the forest, e.g., the first tree (index 0)
tree_to_plot = fit.estimators_[0]

# Plot the decision tree
plt.figure(figsize=(20, 10))
plot_tree(tree_to_plot, feature_names=train_x.columns.tolist(), filled=True, rounded=True, fontsize=10)
plt.title("Decision Tree from Random Forest")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 9))
ax.plot(train_y.values, color='tab:blue')
ax.plot(predictions, color='tab:red')

# %%
# représenter les prévisions sur le test, identifier et comprendre le problème
test_x = test.loc[:,~test.columns.isin(["date","uspop"])]
test_y = test["uspop"]
test_predict = fit.predict(test_x)
print(test_predict)
# Out:
# [57.564 57.564 57.564 57.564 57.564 57.564 57.564 57.564]

# %%
# !pip3 install lazypredict

# import lazypredict
# from lazypredict.Supervised import LazyRegressor

# reg = LazyRegressor(predictions=True)
# models, predictions = reg.fit(train_x, test_x, train_x, test_x)
